# %%
import pandas as pd
from googleapiclient.discovery import build

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Masukkan API Key
API_KEY = 'AIzaSyCb_HPp-b90Il4Kzz6UFeV9aid78XrMZ1E'
youtube = build('youtube', 'v3', developerKey=API_KEY)

# Masukkan ID Video YouTube
video_ids = [
    'cuL4Fl0RZII',
    'mz117p4_v2U',
    'dcE80aReHoU',
    'G7NfecMdGPE',
    'MoGAbf70wms',
    '8YITikwT9dM',
    'P9Q8J0UqKno',
    'DsOjjkPdP4A',
    '-TyJuaqOC-o',
    'BVeqk4An2IA',
    'TAvJFgfOi2Q',
    'iRcdUlXnnhY',
    'cjypb9NExf0',
    'dpBcR5viwCE',
    'O9W1wjzxyyI',
    'h_5w2olHow8',
    'QyHjzkF2uMs',
    'tQAkyWNuN-U',
    'n-Y5FhDL1Hk',
    '5FfbDtDiJ5A',
    'yZTbIcGRVbs',
    'Vq_NfyPdJjA'
]

all_comments = []

def get_replies(parent_id, video_id):
    """Fungsi khusus untuk menarik balasan dari sebuah komentar"""
    request = youtube.comments().list(
        part="snippet",
        parentId=parent_id,
        maxResults=100,
        textFormat="plainText"
    )

    while request:
        response = request.execute()
        for item in response['items']:
            reply = item['snippet']
            all_comments.append({
                'video_id': video_id,
                'comment_type': 'Reply',
                'author': reply['authorDisplayName'],
                'comment_text': reply['textDisplay'],
                'like_count': reply['likeCount'],
                'published_at': reply['publishedAt']
            })

        if 'nextPageToken' in response:
            request = youtube.comments().list(
                part="snippet",
                parentId=parent_id,
                pageToken=response['nextPageToken'],
                maxResults=100,
                textFormat="plainText"
            )
        else:
            break

def get_comments_from_video(video_id):
    print(f"Menarik komentar dari video: {video_id}...")
    request = youtube.commentThreads().list(
        part="snippet",
        videoId=video_id,
        maxResults=100,
        textFormat="plainText"
    )

    while request:
        response = request.execute()

        for item in response['items']:
            # Ekstrak komentar utama
            comment = item['snippet']['topLevelComment']['snippet']
            parent_id = item['snippet']['topLevelComment']['id']
            reply_count = item['snippet']['totalReplyCount']

            all_comments.append({
                'video_id': video_id,
                'comment_type': 'Top-Level',
                'author': comment['authorDisplayName'],
                'comment_text': comment['textDisplay'],
                'like_count': comment['likeCount'],
                'published_at': comment['publishedAt']
            })

            # Jika ada balasan, panggil fungsi get_replies
            if reply_count > 0:
                get_replies(parent_id, video_id)

        if 'nextPageToken' in response:
            request = youtube.commentThreads().list(
                part="snippet",
                videoId=video_id,
                pageToken=response['nextPageToken'],
                maxResults=100,
                textFormat="plainText"
            )
        else:
            break

# Eksekusi
for vid in video_ids:
    try:
        get_comments_from_video(vid)
    except Exception as e:
        print(f"Terjadi kesalahan pada video {vid}: {e}")

# Membuat dataframe
df = pd.DataFrame(all_comments)
print(f"Total {len(df)} komentar berhasil di ambil")
# Out:
# Menarik komentar dari video: cuL4Fl0RZII...
# Menarik komentar dari video: mz117p4_v2U...
# Menarik komentar dari video: dcE80aReHoU...
# Menarik komentar dari video: G7NfecMdGPE...
# Menarik komentar dari video: MoGAbf70wms...
# Menarik komentar dari video: 8YITikwT9dM...
# Menarik komentar dari video: P9Q8J0UqKno...
# Menarik komentar dari video: DsOjjkPdP4A...
# Menarik komentar dari video: -TyJuaqOC-o...
# Menarik komentar dari video: BVeqk4An2IA...
# Menarik komentar dari video: TAvJFgfOi2Q...
# Menarik komentar dari video: iRcdUlXnnhY...
# Menarik komentar dari video: cjypb9NExf0...
# Menarik komentar dari video: dpBcR5viwCE...
# Menarik komentar dari video: O9W1wjzxyyI...
# Menarik komentar dari video: h_5w2olHow8...
# Menarik komentar dari video: QyHjzkF2uMs...
# Menarik komentar dari video: tQAkyWNuN-U...
# Menarik komentar dari video: n-Y5FhDL1Hk...
# Menarik komentar dari video: 5FfbDtDiJ5A...
# Menarik komentar dari video: yZTbIcGRVbs...
# Menarik komentar dari video: Vq_NfyPdJjA...
# Total 11494 komentar berhasil di ambil

# %%
df.head(10)
# Out:
#       video_id comment_type                     author  \
# 0  cuL4Fl0RZII    Top-Level          @TortoiseSemporna
# 1  cuL4Fl0RZII    Top-Level          @khairulhafiz6699
# 2  cuL4Fl0RZII    Top-Level           @Dederahmadi-s3t
# 3  cuL4Fl0RZII    Top-Level          @AndriNurgiansyah
# 4  cuL4Fl0RZII    Top-Level  @mohammadkhamisfamily4524
# 5  cuL4Fl0RZII    Top-Level                @sambers123
# 6  cuL4Fl0RZII    Top-Level        @MimiesitiMimiesiti
# 7  cuL4Fl0RZII    Top-Level        @MimiesitiMimiesiti
# 8  cuL4Fl0RZII    Top-Level             @smokinaces979
# 9  cuL4Fl0RZII    Top-Level               @BocilCengos
#
#                                         comment_text  like_count  \
# 0  Penipu betul perempuan blonde ini. Sama dgn Tr...           0
# 1  Tidak boleh diterima????? Tanpa rasa malu peny...           0
# 2             Konoha konoha beritanya ngibul trus...           0
# 3  PBB cm bisa mengecam doang tapi tidak bisa ber...           0
# 4                                      Amerika rasis           0
# 5  Ini politik Konoha TDK bisa selami apa 7 an se...           0
# 6  Palestin memerlukan 100thn untuk dibina semula...           0
# 7  Ya Allah lindungi negara Iran. Berikanlah keme...           0
# 8                                musibat punya trump           0
# 9        Si Israel tuh jinakan dulu biar cepet damai           0
#
#            published_at
# 0  2026-04-11T09:59:11Z
# 1  2026-04-10T15:10:03Z
# 2  2026-04-10T13:54:38Z
# 3  2026-04-10T10:53:18Z
# 4  2026-04-10T07:17:00Z
# 5  2026-04-10T05:59:48Z
# 6  2026-04-10T05:57:08Z
# 7  2026-04-10T05:37:22Z
# 8  2026-04-10T05:21:21Z
# 9  2026-04-10T03:56:10Z

# %%
# Menyimpan data ke CSV menggunakan Pandas
df = pd.DataFrame(all_comments)
df.to_csv('/content/drive/MyDrive/Kuliah/Semester 6/Jurnal/dataset_komentar_youtube_11k.csv', index=False, encoding='utf-8')

print(f"Selesai! Total {len(df)} komentar berhasil disimpan ke dataset_komentar_youtube.csv")
# Out:
# Selesai! Total 11494 komentar berhasil disimpan ke dataset_komentar_youtube.csv
